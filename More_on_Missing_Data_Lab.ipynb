# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaAloo/Diana-s-Jupyter--lab/blob/master/More_on_Missing_Data_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # More on Missing Data - Lab
#
# ## Introduction
#
# In this lab, you'll continue to practice techniques for dealing with missing data. Moreover, you'll observe the impact on distributions of your data produced by various techniques for dealing with missing data.
#
# ## Objectives
#
# In this lab you will:
#
# - Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset
# - Determine how the distribution of data is affected by imputing values

# %% [markdown]
# ## Load the data
#
# To start, load the dataset `'titanic.csv'` using pandas.

# %%
# Your code here
import pandas as pd
df = pd.read_csv('titanic.csv')
df.head()
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Use the `.info()` method to quickly preview which features have missing data

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    object
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %% [markdown]
# ## Observe previous measures of centrality
#
# Let's look at the `'Age'` feature. Calculate the mean, median, and standard deviation of this feature. Then plot a histogram of the distribution.

# %%
# Your code here
mean_age = df['Age'].mean()
median_age = df['Age'].median()
std_age = df['Age'].std()

print(f"Mean Age: {mean_age:.2f}")
print(f"Median Age: {median_age:.2f}")
print(f"Standard Deviation of Age: {std_age:.2f}")
df['Age'].hist(bins=30, edgecolor='black')
plt.title('Distribution of Passenger Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()
# Out:
# Mean Age: 29.70
# Median Age: 28.00
# Standard Deviation of Age: 14.53

# %% [markdown]
# ## Impute missing values using the mean
#
# Fill the missing `'Age'` values using the average age. (Don't overwrite the original data, as we will be comparing to other methods for dealing with the missing values.) Then recalculate the mean, median, and std and replot the histogram.

# %%
# Your code here
age_mean_imputed = df['Age'].fillna(df['Age'].mean())
mean_age = age_mean_imputed.mean()
median_age = age_mean_imputed.median()
std_age = age_mean_imputed.std()
print(f"[Mean Imputation] Mean Age: {mean_age:.2f}")
print(f"[Mean Imputation] Median Age: {median_age:.2f}")
print(f"[Mean Imputation] Standard Deviation: {std_age:.2f}")
age_mean_imputed.hist(bins=30, edgecolor='black')
plt.title('Age Distribution (Missing Filled with Mean)')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()
# Out:
# [Mean Imputation] Mean Age: 29.70
# [Mean Imputation] Median Age: 29.70
# [Mean Imputation] Standard Deviation: 13.00

# %% [markdown]
# ### Commentary
#
# Note that the standard deviation dropped, the median was slightly raised and the distribution has a larger mass near the center.

# %% [markdown]
# ## Impute missing values using the median
#
# Fill the missing `'Age'` values, this time using the median age. (Again, don't overwrite the original data, as we will be comparing to other methods for dealing with the missing values.) Then recalculate the mean, median, and std and replot the histogram.

# %%
# Your code here
age_median_imputed = df['Age'].fillna(df['Age'].median())
mean_age = age_median_imputed.mean()
median_age = age_median_imputed.median()
std_age = age_median_imputed.std()
print(f"[Median Imputation] Mean Age: {mean_age:.2f}")
print(f"[Median Imputation] Median Age: {median_age:.2f}")
print(f"[Median Imputation] Standard Deviation: {std_age:.2f}")
age_median_imputed.hist(bins=30, edgecolor='black')
plt.title('Age Distribution (Missing Filled with Median)')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()
# Out:
# [Median Imputation] Mean Age: 29.36
# [Median Imputation] Median Age: 28.00
# [Median Imputation] Standard Deviation: 13.02

# %% [markdown]
# ### Commentary
#
# Imputing the median has similar effectiveness to imputing the mean. The variance is reduced, while the mean is slightly lowered. You can once again see that there is a larger mass of data near the center of the distribution.

# %% [markdown]
# ## Dropping rows
#
# Finally, let's observe the impact on the distribution if we were to simply drop all of the rows that are missing an age value. Then, calculate the mean, median and standard deviation of the ages along with a histogram, as before.

# %%
# Your code here
age_dropped = df['Age'].dropna()
mean_age = age_dropped.mean()
median_age = age_dropped.median()
std_age = age_dropped.std()
print(f"[Dropped Missing] Mean Age: {mean_age:.2f}")
print(f"[Dropped Missing] Median Age: {median_age:.2f}")
print(f"[Dropped Missing] Standard Deviation: {std_age:.2f}")
age_dropped.hist(bins=30, edgecolor='black')
plt.title('Age Distribution (Missing Dropped)')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()
# Out:
# [Dropped Missing] Mean Age: 29.70
# [Dropped Missing] Median Age: 28.00
# [Dropped Missing] Standard Deviation: 14.53

# %% [markdown]
# ### Commentary
#
# Dropping missing values leaves the distribution and associated measures of centrality unchanged, but at the cost of throwing away data.
#
# ## Summary
#
# In this lab, you briefly practiced some common techniques for dealing with missing data. Moreover, you observed the impact that these methods had on the distribution of the feature itself. When you begin to tune models on your data, these considerations will be an essential process of developing robust and accurate models.
